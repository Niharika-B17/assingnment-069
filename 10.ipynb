# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-76d05ebf-5c3c-4c67-97e1-9a5243b1246d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76d05ebf-5c3c-4c67-97e1-9a5243b1246d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#mean value of SAT score
np.mean(df["SAT"])
# Out:
# 1266.44

# %%
#median
np.median(df["SAT"])
# Out:
# 1285.0

# %%
np.std(df['GradRate'])
# Out:
# 8.874773236539623

# %%
np.var(df['SFRatio'])
# Out:
# 15.881599999999999

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Acceptance Ratio")
plt.hist(df["Accept"])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df["Accept"], kde = True)
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
#Observation: it is a right skewed and non symmetrical

# %%
plt.figure(figsize=(6,3))
plt.title("SAT Ratio")
plt.hist(df["SAT"])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df["SAT"], kde = True)
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
#its a right skewed and non symmetric

# %%
plt.figure(figsize=(6,3))
plt.title("SFRatio")
plt.hist(df["SFRatio"])
# Out:
# (array([2., 2., 6., 8., 2., 2., 2., 0., 0., 1.]),
#  array([ 6. ,  7.9,  9.8, 11.7, 13.6, 15.5, 17.4, 19.3, 21.2, 23.1, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df["SFRatio"], kde = True)
# Out:
# <Axes: xlabel='SFRatio', ylabel='Count'>

# %%
#it is le

# %%
s1 = [20,15,10,25,3035,28,40,45,60]
scores1 = pd.Series(s1)
scores1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-372c55b729b5> in <cell line: 0>()
#       1 s1 = [20,15,10,25,3035,28,40,45,60]
# ----> 2 scores1 = pd.Series(s1)
#       3 scores1
#
# NameError: name 'pd' is not defined

# %%
import matplotlib.pyplot as plt
plt.boxplot(scores1, vert=False)
